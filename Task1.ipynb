# %%
import pandas as pd

# %%
df = pd.read_csv('Population.csv',skiprows=4)

# %%
df.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                Indicator Name     Indicator Code       1960  \
# 0  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  50.858849
# 1  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  50.387880
# 2  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  48.083054
# 3  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  50.179683
# 4  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  49.843790
#
#         1961       1962       1963       1964       1965  ...       2014  \
# 0  50.850191  50.845065  50.836016  50.826773  50.823381  ...  52.515590
# 1  50.388814  50.391276  50.395656  50.400512  50.405510  ...  50.559167
# ...

# %%
df=df.drop(columns=['Unnamed: 67'])

# %%
df.head(10)
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
# 5                      Albania          ALB
# 6                      Andorra          AND
# 7                   Arab World          ARB
# 8         United Arab Emirates          ARE
# 9                    Argentina          ARG
#
#                                Indicator Name     Indicator Code       1960  \
# 0  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  50.858849
# 1  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  50.387880
# 2  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  48.083054
# 3  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  50.179683
# 4  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  49.843790
# ...

# %%
df.shape
# Out:
# (266, 67)

# %%
dist=df.loc[[2,8]].copy()

# %%
dist
# Out:
#            Country Name Country Code  \
# 2           Afghanistan          AFG
# 8  United Arab Emirates          ARE
#
#                                Indicator Name     Indicator Code       1960  \
# 2  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  48.083054
# 8  Population, female (% of total population)  SP.POP.TOTL.FE.ZS  39.234482
#
#         1961       1962       1963       1964       1965  ...       2013  \
# 2  48.165001  48.242372  48.315893  48.385273  48.450285  ...  49.442103
# 8  38.912217  38.652042  38.431652  38.234778  38.059345  ...  28.281139
#
#         2014       2015       2016       2017       2018       2019  \
# 2  49.432135  49.423184  49.414608  49.419284  49.437209  49.455485
# 8  28.612393  28.927601  29.225307  29.507319  29.778859  30.047189
#
#         2020       2021       2022
# 2  49.470944  49.488405  49.508722
# 8  30.277092  30.465177  30.646600
#
# [2 rows x 67 columns]

# %%
import matplotlib.pyplot as ply

# %%
dist=dist[['Country Name','2022']]

# %%
dist
# Out:
#            Country Name       2022
# 2           Afghanistan  49.508722
# 8  United Arab Emirates  30.646600

# %%
dist["Men2022"] = 100 - dist["2022"]
# Out:
# C:\Users\Sathak\AppData\Local\Temp\ipykernel_13172\653000901.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dist["Men2022"] = 100 - dist["2022"]

# %%
dist.rename(columns={'2022':'Women','Men2022':'Men'},inplace=True)
# Out:
# C:\Users\Sathak\AppData\Local\Temp\ipykernel_13172\1753816602.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dist.rename(columns={'2022':'Women','Men2022':'Men'},inplace=True)

# %%
dist
# Out:
#            Country Name      Women        Men
# 2           Afghanistan  49.508722  50.491278
# 8  United Arab Emirates  30.646600  69.353400

# %%
dist.plot(x='Country Name',xlabel='Percentage',ylabel='Country',kind="bar",title='Distribution of Population in 2022')
# Out:
# <Axes: title={'center': 'Distribution of Population in 2022'}, xlabel='Percentage', ylabel='Country'>
